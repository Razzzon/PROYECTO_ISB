# %% [markdown]
# <img src="https://raw.githubusercontent.com/ulewis/Ejemplos/main/Im%C3%A1genes/PORTADA_PI1.png" alt="UPCH" width="800">

# %% [markdown]
# # **1. Recordando**
# ---

# %% [markdown]
# **Cuadernos de Jupyter Notebook/Google Colab**
#
# * La forma tradicional de ejecutar un programa en python es con el comando **python nombre.py** a través de la consola, donde nombre.py es un archivo con código fuente python.
#
# * En lugar de eso, para este curso utilizaremos un servidor de Jupyter Notebook con cuadernos de código. Estos cuadernos (notebooks) nos permiten combinar texto y código, organizados en celdas, lo cual es más cómodo para probar cosas nuevas y documentar lo que hacemos conforme vamos explorando.
# * Como se indicó, este curso se realizará completamente en **google Colab** evitando problemas de instalación a los alumnos.
#
# **Uso de Cuadernos**
#
# * Los cuadernos tienen dos tipos de celdas: de **CÓDIGO** y **TEXTO**. **La celda que estás leyendo** es una celda de TEXTO escrita con Markdown, un lenguaje de marcado parecido al que utiliza wikipedia para sus páginas o al HTML.
#
# * Las celdas de código son ejecutables, es decir, se pueden ejecutar individualmente (con **ctrl + enter**)
#
# **Uso de ChatGPT**
#
# * Para este curso es obligatorio el uso de [ChatGPT](https://chat.openai.com/)

# %% [markdown]
# ## **`Bienvenidos a esta primera clase`**

# %%
#ESTA ES UNA CELDA DE CÓDIGO
# CTRL + ENTER para ejecutarla o clic en el boton de play |>|

print(3+5)
print("Hola mundo")
# Out:
# 8
# Hola mundo

# %%
(10+2)*0
print("razzon")
# Out:
# razzon

# %% [markdown]
# # **2. Tipos de datos básicos en Python**
# ---

# %% [markdown]
# >## **Tipado Dinámico**

# %% [markdown]
# En Python existe el famos tipado dinámico
# * El valor de las variables se cambia de forma directa, y se  pueden hacer conversiones de tipos de datos.

# %%
# CREAMOS INICIALMENTE UNA VARIABLE DEL TIPO NUMÉRICO
numero = 5.0
print("el número es : ")
print(numero)
print(type(numero))
# Out:
# el número es :
# 5.0
# <class 'float'>

# %%
print(type(numero))# DE FORMA DIRECTA CAMBIAMOS EL CONTENIDO DE LA VARIABLE.
#ESTA SE AJUSTA Y CONVIERTE AL TIPO DE DATOS SEGÚN SU ENTRADA
numero = "hola"
print(type(numero))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# >## **Variables**
#
# ---

# %% [markdown]
# Una variable almacena un valor y se le asigna un nombre. Hay diversos tipos de variables y obedecen a diferentes propósitos.
#
# Debemos tener en cuenta:
# * Las variables en python **no necesitan** ser declaradas. No se necesita indicar el tipo de dato en las asignaciones. Solo se realiza esto, cuando realizamos conversiones de tipos de datos.
#
# * Las variables son **sensibles a Mayúsculas y minúsculas**.
#
# * Los comentarios son de dos tipos:
#  * Usando el caracter **#** para una linea
#  * Usando tres aspas simples ''' para abrir y cerrar comentarios grandes.
#
# * En Python existen **3 tipos de Datos Basicos** (entero, string e booleano).
#
# Ahora veremos los tres tipos de datos básicos que una variable puede ser:

# %%
var = 10
print(type(var))

var = 10.1
print(type(var))

var = "Hola"
print(type(var))

var = True
print(type(var))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# hola esta es una linea de codigo comentada
# '''
# hola como estan todos
# yo estoy bien
# y ustedes ¿Cómo están?
# '''

# %% [markdown]
# >###  **Datos Numéricos**
#
# ---

# %%
# VARIABLES ENTERAS
num_int = 10          # No se necesita punto y coma al final
print(num_int)        # Imprimir en consola el valor de la variable
print(type(num_int))  # "type" muestra el tipo de dato que es mi variable
# Out:
# 10
# <class 'int'>

# %%
# VARIABLES FLOTANTES
num_float = 10.5          # Los flotantes son números con punto decimal
print(num_float)
print(type(num_float))
# Out:
# 10.5
# <class 'float'>

# %%
# NÚMEROS COMPLEJOS
# R + aj
num_compl = 5 + 2j
print(num_compl.real)
print(num_compl.imag)
print(num_compl)
print(type(num_compl))
# Out:
# 5.0
# 2.0
# (5+2j)
# <class 'complex'>

# %%
# TAMBIEN PODEMOS DEFINIR NUMEROS EN EL SISTEMA OCTAL
num_base_8 = 0o6217   # 271 en decimal
print(num_base_8)
# Out:
# 3215

# %%
# LO MISMO PASA CON EL SISTEMA HEXADECIMAL
num_base_16 = 0x1524  # 292 en decimal
print(num_base_16)
# Out:
# 5412

# %% [markdown]
# >###  **Datos del Tipo String o cadenas de caracteres**
#
# ---

# %%
# SE PUEDEN USAR ASPAS DOBLES PARA DEFINIR UN STRING
texto_asp_dob = "¡Hola estudiantes de la Universidad Peruana Cayetano Heredia !"
print(texto_asp_dob)
print(type(texto_asp_dob))
# Out:
# ¡Hola estudiantes de la Universidad Peruana Cayetano Heredia !
# <class 'str'>

# %%
# TAMBIEN, SE PUEDEN USAR ASPAS SIMPLES ...
texto_asp_simp = 'hola amigos'
print(texto_asp_simp)
# Out:
# hola amigos

# %%
# Y ¿SI QUEREMOS MOSTRASLAS ASPAS EN LA SALIDA DEL TEXTO? PUES, TODO BIEN ...
text_asp_dentro = " 'hola amigos' "
print(text_asp_dentro)
# Out:
#  'hola amigos'

# %%
texto_asp_simp = ' "hola amigos" '
print(texto_asp_simp)
# Out:
#  "hola amigos"

# %% [markdown]
# >###  **Datos del Tipo Booleano**
#
# ---
# *   La primera letra debe estar siempre en Mayusculas con **T** para VERDADERO
# *   La primera letra debe estar siempre en Mayusculas con **F** para FALSO
# * Python implementa todos los operadores usuales de la lógica booleana, usando palabras en inglés **(and, or, not)** en lugar de símbolos (||, &&, !, etc).
#
# También se tienen los típicos operadores de comparación:
#
# <table align="left">
# <thead>
# <tr>
# <th>Símbolo</th>
# <th>Significado</th>
# <th>Ejemplo</th>
# <th>Resultado</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>==</code></td>
# <td>Igual que</td>
# <td><code>5 == 7</code></td>
# <td><code>False</code></td>
# </tr>
# <tr>
# <td><code>!=</code></td>
# <td>Distinto que</td>
# <td><code>rojo != verde</code></td>
# <td><code>True</code></td>
# </tr>
# <tr>
# <td><code>&lt;</code></td>
# <td>Menor que</td>
# <td><code>8 &lt; 12</code></td>
# <td><code>True</code></td>
# </tr>
# <tr>
# <td><code>&gt;</code></td>
# <td>Mayor que</td>
# <td><code>12 &gt; 7</code></td>
# <td><code>True</code></td>
# </tr>
# <tr>
# <td><code>&lt;=</code></td>
# <td>Menor o igual que</td>
# <td><code>12 &lt;= 12</code></td>
# <td><code>True</code></td>
# </tr>
# <tr>
# <td><code>&gt;=</code></td>
# <td>Mayor o igual que</td>
# <td><code>4 &gt;= 5</code></td>
# <td><code>False</code></td>
# </tr>
# </tbody>
# </table>

# %%
valor_A = True
print(valor_A)
# Out:
# True

# %%
valor_B = False
print(valor_B)
# Out:
# False

# %%
print(not valor_B)
# Out:
# True

# %%
# A and B or A
print(valor_A and valor_B or valor_A)
# Out:
# True

# %%
# B and B or (A and B) and (A or A)

print(valor_B and valor_B or (valor_A and valor_B) and (valor_A or valor_A))
# Out:
# False

# %%
# (B != A) and (A == not B)

print((valor_B != valor_A) and (valor_A == (not valor_B)))
# Out:
# True

# %%
# (not A == not B) and [(B) or (not B or A)]

# %% [markdown]
# >###  **El comando PRINT()**
#
# ---
#
# * El comando print() nos permite mostrar en la pantalla el contenido de nuestras variables, asi como mensajes.
# * Existen diferentes formas de mostrarr los valores de nuestras variables

# %%
num_1 = 8
num_2 = 2

resultado = (num_1 + num_2)/3.0

# %%
print(resultado)
# Out:
# 3.3333333333333335

# %%
print("El resultado de", num_1, "mas", num_2, "es", resultado)
# Esta es una forma típica
# Out:
# El resultado de 8 mas 2 es 3.3333333333333335

# %%
print("El resultado de {} mas {} es {:.2f}".format(num_1, num_2, resultado))
# Este es el método más usado en Python2.x
# Out:
# El resultado de 8 mas 2 es 3.33

# %%
print(f"El resultado de {num_1} mas {num_2} es {resultado:.1f}")
# Este es el nuevo formato desde Python 3, más ordenado para redondeo
# Out:
# El resultado de 8 mas 2 es 3.3

# %% [markdown]
# # **3. Operadores Aritméticos en Python**
# ---

# %% [markdown]
# ```
# ----------------------------------------------------------
#  Símbolo  Significado        Ejemplo            Resultado
#    +       suma              a = 10 + 5         a es 15
#    -       resta             a = 12 - 7         a es  5
#    -       negaciòn          a = -5             a es -5
#    *       multiplicación    a = 7 * 5          a es 35
#   **       potencia          a = 2 ** 3         a es  8
#    /       división          a = 12.5 / 2       a es  6.25
#   //       división entera  a = 12.5 // 2      a es  6.0
#    %       módulo            a = 27 % 4         a es  3
# ----------------------------------------------------------
# ```
# SUGERENCIA:
# Coloque siempre un espacio en blanco antes y despues de un operador

# %% [markdown]
# **Ejemplo de Suma**

# %%
num_1 = 10
num_2 = 15

valor = num_1 + num_2

print(f"El resultado de {num_1} más {num_2} es {valor}")
# Out:
# El resultado de 10 más 15 es 25

# %% [markdown]
# **Ejemplo de Substracción**

# %%
valor = num_1 - num_2
print(f"El resultado de {num_1} menos {num_2} es {valor}")
# Out:
# El resultado de 10 menos 15 es -5

# %% [markdown]
# **Ejemplo de Negación**

# %%
valor = - num_1

print(f"La negación de {num_1} es {valor}")
print("La negación de {} es {}".format(num_1, valor))
# Out:
# La negación de 10 es -10
# La negación de 10 es -10

# %% [markdown]
# **Ejemplo de Multiplicación**

# %%
valor = num_1 * num_2
print(f"El resutlado de {num_1} por {num_2} es {valor}")
print("El resultado de {} por {} es {}".format(num_1, num_2, valor))
# Out:
# El resutlado de 10 por 15 es 150
# El resultado de 10 por 15 es 150

# %% [markdown]
# **Ejemplo de División**

# %%
valor = num_1 / num_2
print(f"La division de {num_1} con {num_2} es {valor}")     # Sin redondear
print(f"La division de {num_1} con {num_2} es {valor:.4f}") # Redondeando
# Out:
# La division de 10 con 15 es 0.6666666666666666
# La division de 10 con 15 es 0.6667

# %% [markdown]
# **Ejemplo de Divisón entera y modulo**

# %%
# cociente
valor = num_2 // num_1
print(f"el cociente de dividir {num_2} entre {num_1} es {valor}")

# modulo o resto
valor = num_2 % num_1
print(f"el modulo de dividir {num_2} entre {num_1} es {valor}")
# Out:
# el cociente de dividir 15 entre 10 es 1
# el modulo de dividir 15 entre 10 es 5

# %% [markdown]
# **Ejemplo de Potencia**

# %%
pot = 3
valor = num_1 ** pot

print(f"{num_1} elevado al {pot} es {valor}")
# Out:
# 10 elevado al 3 es 1000

# %% [markdown]
# # **4. Asignaciones en Python**
# ---

# %% [markdown]
# Si queremos intercambiar el valor de dos o más variables podemos hacer lo siguiente:

# %%
a = 10
b = 25
c = 15
d = 38

print(f"a es {a}, b es {b}, c es {c}, d es {d}")

a, b, c, d = b, a, d, c


print(f"a es {a}, b es {b}, c es {c}, d es {d}")
# Out:
# a es 10, b es 25, c es 15, d es 38
# a es 25, b es 10, c es 38, d es 15

# %% [markdown]
# # **5. Conversión de Datos en Python**
# ---

# %%
# CONNVERSION DE STRING A NÚMERO
var_str = "100"
print(type(var_str))

var_int = int(var_str)
print(type(var_int))

var_flt = float(var_str)
print(type(var_flt))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
# CONNVERSION DE NÚMERO A STRING
var_num = 10
print(type(var_num))

var = str(var_num)
print(type(var))

var = abs(-10)
print(var)
# Out:
# <class 'int'>
# <class 'str'>
# 10

# %% [markdown]
# # **RECOMENDACIONES DE PROGRAMACION**
#
#
#
# 1.   Para las Variables:
#
#   *   Usar nombres descriptivos y en minúsculas.
#   *   Para nombres compuestos, separar las palabras con sublinea.
#   *   Antes y despues de un operador (+,/,-,=, etc) debe haber (e apenas un) espacio en blanco.
#
# 2. Para Constantes
#
#   *   Usar nombres descriptivos y en Mayusculas.
#   *   Para nombres compuestos, separar las palabras con sublinea.

# %%
num_ejemplo = 10
MI_CONSTANTE = 10
